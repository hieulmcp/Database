# %%
import facebook

# %%
# truy cập bằng page token
access_token = 'EAAHwWw29kTMBAErKl06UTk2PoZByQqg3yrXkCuT4UwKdjEtSuIjO7oZCDMLEdwoLzTz7ZBnZClbx5i60MKongZAHmAJNKl8Trzw8XdC8udPzmCDyGwkpsT0EXAPueyHviL8gmZCPOvxEwxrDCO4EVoKnfVQwZBjXKgCpeCo3pRnYZARL2572LY4MZBXuxVMo0ZAM4VK45F23ZC7wQzWOyd9KKOG'
graph = facebook.GraphAPI(access_token)

# %%
# Write 'Hello, world' to the active user's wall.
# cấp pages_read_engagement, pages_manage_posts, pages_read_user_content
graph.put_object(parent_object='me', connection_name='feed',
                  message='Hello, world')
# Out:
# {'id': '100977415573772_101552475516266'}

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# Add a link and write a message about it.
data = graph.put_object(
   parent_object="me",
   connection_name="feed",
   message="This is a great website. Everyone should visit it.",
   link="https://www.facebook.com")
data
# Out:
# {'id': '100977415573772_101559895515524'}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Write a comment on a post. Quyen pages_manage_engagement
graph.put_object(parent_object=data['id'], connection_name='comments', message='First!')
# Out:
# {'id': '101559895515524_101559938848853'}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
comment = graph.put_comment(object_id=data['id'], message='Great post...')
comment
# Out:
# {'id': '101559895515524_101559952182185'}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
graph.put_like(object_id=comment['id'])
# Out:
# {'success': True}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
graph.delete_object(id=data['id'])
# Out:
# {'success': True}
