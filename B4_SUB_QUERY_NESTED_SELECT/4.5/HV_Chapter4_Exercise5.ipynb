# %% [markdown]
# ## Chapter 4 – Exercise 5:  Sử dụng Magic SQL thực hiện lại các bài tập trong phần Chapter 4 – Exericise 2

# %% [markdown]
# #### Học viên thực hiện các yêu cầu sau và đối chiếu với kết quả cho trước:

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# chuan bi thong tin ket noi MySQL
server ='localhost'
db = 'salesdb'
username = 'root'
pwd = ''

# ket noi MySQL
connection_string = "mysql+pymysql://{user}:{password}@{host}/{database}?charset=UTF8". \
    format(user=username, password=pwd, host=server, database=db)
# %sql $connection_string

# %%
# Câu 1: Liệt kê danh sách các khách hàng ở Brazil, duyệt và xuất ra từng dòng dữ liệu thỏa điều kiện
q = "select * from customers where country = 'Brazil'" # Magic SQL: Brazil chi duoc dung apostrophe, khong dung double quotes
# %sql $q
# Out:
#  * mysql+pymysql://root:***@localhost/salesdb?charset=UTF8
# 9 rows affected.
# [(15, 'Pedro', 'Afonso', 'Sao Paulo', 'Brazil', '(11) 555-7647'),
#  (21, 'Aria', 'Cruz', 'Sao Paulo', 'Brazil', '(11) 555-9857'),
#  (31, 'André', 'Fonseca', 'Campinas', 'Brazil', '(11) 555-9482'),
#  (34, 'Mario', 'Pontes', 'Rio de Janeiro', 'Brazil', '(21) 555-0091'),
#  (61, 'Bernardo', 'Batista', 'Rio de Janeiro', 'Brazil', '(21) 555-4252'),
#  (62, 'Lúcia', 'Carvalho', 'Sao Paulo', 'Brazil', '(11) 555-1189'),
#  (67, 'Janete', 'Limeira', 'Rio de Janeiro', 'Brazil', '(21) 555-3412'),
#  (81, 'Anabela', 'Domingues', 'Sao Paulo', 'Brazil', '(11) 555-2167'),
#  (88, 'Paula', 'Parente', 'Resende', 'Brazil', '(14) 555-8122')]

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_html rendered_html output_result"><table>
#     <tbody><tr>
#         <th>Id</th>
#         <th>FirstName</th>
#         <th>LastName</th>
#         <th>City</th>
#         <th>Country</th>
#         <th>Phone</th>
#     </tr>
#     <tr>
#         <td>15</td>
#         <td>Pedro</td>
#         <td>Afonso</td>
#         <td>Sao Paulo</td>
#         <td>Brazil</td>
#         <td>(11) 555-7647</td>
#     </tr>
#     <tr>
#         <td>61</td>
#         <td>Bernardo</td>
#         <td>Batista</td>
#         <td>Rio de Janeiro</td>
#         <td>Brazil</td>
#         <td>(21) 555-4252</td>
#     </tr>
#     <tr>
#         <td>62</td>
#         <td>Lúcia</td>
#         <td>Carvalho</td>
#         <td>Sao Paulo</td>
#         <td>Brazil</td>
#         <td>(11) 555-1189</td>
#     </tr>
#     <tr>
#         <td>21</td>
#         <td>Aria</td>
#         <td>Cruz</td>
#         <td>Sao Paulo</td>
#         <td>Brazil</td>
#         <td>(11) 555-9857</td>
#     </tr>
#     <tr>
#         <td>81</td>
#         <td>Anabela</td>
#         <td>Domingues</td>
#         <td>Sao Paulo</td>
#         <td>Brazil</td>
#         <td>(11) 555-2167</td>
#     </tr>
#     <tr>
#         <td>31</td>
#         <td>André</td>
#         <td>Fonseca</td>
#         <td>Campinas</td>
#         <td>Brazil</td>
#         <td>(11) 555-9482</td>
#     </tr>
#     <tr>
#         <td>67</td>
#         <td>Janete</td>
#         <td>Limeira</td>
#         <td>Rio de Janeiro</td>
#         <td>Brazil</td>
#         <td>(21) 555-3412</td>
#     </tr>
#     <tr>
#         <td>88</td>
#         <td>Paula</td>
#         <td>Parente</td>
#         <td>Resende</td>
#         <td>Brazil</td>
#         <td>(14) 555-8122</td>
#     </tr>
#     <tr>
#         <td>34</td>
#         <td>Mario</td>
#         <td>Pontes</td>
#         <td>Rio de Janeiro</td>
#         <td>Brazil</td>
#         <td>(21) 555-0091</td>
#     </tr>
# </tbody></table></div>
#
# </details>

# %%
# Câu 2: Liệt kê danh sách các nhà cung cấp không có số Fax, duyệt và xuất ra từng dòng dữ liệu thỏa điều kiện
q = "select from suppliers where is null"
# %sql $q
# Out:
#  * mysql+pymysql://root:***@localhost/salesdb?charset=UTF8
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'from suppliers where is null' at line 1")
# [SQL: select from suppliers where is null]
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_html rendered_html output_result"><table>
#     <tbody><tr>
#         <th>Id</th>
#         <th>CompanyName</th>
#         <th>ContactName</th>
#         <th>ContactTitle</th>
#         <th>City</th>
#         <th>Country</th>
#         <th>Phone</th>
#         <th>Fax</th>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>Exotic Liquids</td>
#         <td>Charlotte Cooper</td>
#         <td>None</td>
#         <td>London</td>
#         <td>UK</td>
#         <td>(171) 555-2222</td>
#         <td>None</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>New Orleans Ca6/Delights</td>
#         <td>Shelley Burke</td>
#         <td>None</td>
#         <td>New Orleans</td>
#         <td>USA</td>
#         <td>(100) 555-4822</td>
#         <td>None</td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>Tokyo Traders</td>
#         <td>Yoshi Nagase</td>
#         <td>None</td>
#         <td>Tokyo</td>
#         <td>Japan</td>
#         <td>(03) 3555-5011</td>
#         <td>None</td>
#     </tr>
#     <tr>
#         <td>5</td>
#         <td>Cooperativa de Quesos 'Las Cabras'</td>
#         <td>Antonio del Valle Saavedra</td>
#         <td>None</td>
#         <td>Oviedo</td>
#         <td>Spain</td>
#         <td>(98) 598 76 54</td>
#         <td>None</td>
#     </tr>
#     <tr>
#         <td>6</td>
#         <td>Mayumi's</td>
#         <td>Mayumi Ohno</td>
#         <td>None</td>
#         <td>Osaka</td>
#         <td>Japan</td>
#         <td>(06) 431-7877</td>
#         <td>None</td>
#     </tr>
#     <tr>
#         <td>8</td>
#         <td>Specialty Biscuits, Ltd.</td>
#         <td>Peter Wilson</td>
#         <td>None</td>
#         <td>Manchester</td>
#         <td>UK</td>
#         <td>(161) 555-4448</td>
#         <td>None</td>
#     </tr>
#     <tr>
#         <td>10</td>
#         <td>Refrescos Americanas LTDA</td>
#         <td>Carlos Diaz</td>
#         <td>None</td>
#         <td>Sao Paulo</td>
#         <td>Brazil</td>
#         <td>(11) 555 4640</td>
#         <td>None</td>
#     </tr>
#     <tr>
#         <td>11</td>
#         <td>Heli Süßwaren GmbH &amp; Co. KG</td>
#         <td>Petra Winkler</td>
#         <td>None</td>
#         <td>Berlin</td>
#         <td>Germany</td>
#         <td>(010) 9984510</td>
#         <td>None</td>
#     </tr>
#     <tr>
#         <td>12</td>
#         <td>Plutzer Lebensmittelgroßmärkte AG</td>
#         <td>Martin Bein</td>
#         <td>None</td>
#         <td>Frankfurt</td>
#         <td>Germany</td>
#         <td>(069) 992755</td>
#         <td>None</td>
#     </tr>
#     <tr>
#         <td>15</td>
#         <td>Norske Meierier</td>
#         <td>Beate Vileid</td>
#         <td>None</td>
#         <td>Sandvika</td>
#         <td>Norway</td>
#         <td>(0) 2-953010</td>
#         <td>None</td>
#     </tr>
#     <tr>
#         <td>16</td>
#         <td>Bigfoot Breweries</td>
#         <td>Cheryl Saylor</td>
#         <td>None</td>
#         <td>Bend</td>
#         <td>USA</td>
#         <td>(503) 555-9931</td>
#         <td>None</td>
#     </tr>
#     <tr>
#         <td>17</td>
#         <td>Svensk Sjöföda AB</td>
#         <td>Michael Björn</td>
#         <td>None</td>
#         <td>Stockholm</td>
#         <td>Sweden</td>
#         <td>08-123 45 67</td>
#         <td>None</td>
#     </tr>
#     <tr>
#         <td>20</td>
#         <td>Leka Trading</td>
#         <td>Chandra Leka</td>
#         <td>None</td>
#         <td>Singapore</td>
#         <td>Singapore</td>
#         <td>555-8787</td>
#         <td>None</td>
#     </tr>
#     <tr>
#         <td>23</td>
#         <td>Karkki Oy</td>
#         <td>Anne Heikkonen</td>
#         <td>None</td>
#         <td>Lappeenranta</td>
#         <td>Finland</td>
#         <td>(953) 10956</td>
#         <td>None</td>
#     </tr>
#     <tr>
#         <td>25</td>
#         <td>Ma Maison</td>
#         <td>Jean-Guy Lauzon</td>
#         <td>None</td>
#         <td>Montréal</td>
#         <td>Canada</td>
#         <td>(514) 555-9022</td>
#         <td>None</td>
#     </tr>
#     <tr>
#         <td>27</td>
#         <td>Escargots Nouveaux</td>
#         <td>Marie Delamare</td>
#         <td>None</td>
#         <td>Montceau</td>
#         <td>France</td>
#         <td>85.57.00.07</td>
#         <td>None</td>
#     </tr>
# </tbody></table></div>
#
# </details>

# %%
# Câu 3: Liệt kê danh sách tất cả các sản phẩm có đơn giá từ 30 đến 60 usd
q = "select p.*, BIN(p.isdiscontinued) from products p where p.unitprice between 30 and 60"
# %sql $q
# Out:
#  * mysql+pymysql://root:***@localhost/salesdb?charset=UTF8
# 20 rows affected.
# [(7, "Uncle Bob's Organic Dried Pears", 3, Decimal('30'), '12 - 1 lb pkgs.', b'\x00', '0'),
#  (8, 'Northwoods Cranberry Sauce', 3, Decimal('40'), '12 - 12 oz jars', b'\x00', '0'),
#  (10, 'Ikura', 4, Decimal('34'), '12 - 200 ml jars', b'\x00', '0'),
#  (12, 'Queso Manchego La Pastora', 5, Decimal('38'), '10 - 500 g pkgs.', b'\x00', '0'),
#  (17, 'Alice Mutton', 7, Decimal('39'), '20 - 1 kg tins', b'\x01', '1'),
#  (26, 'Gumbär Gummibärchen', 11, Decimal('31'), '100 - 250 g bags', b'\x00', '0'),
#  (27, 'Schoggi Schokolade', 11, Decimal('44'), '100 - 100 g pieces', b'\x00', '0'),
#  (28, 'Rössle Sauerkraut', 12, Decimal('46'), '25 - 825 g cans', b'\x01', '1'),
#  (32, 'Mascarpone Fabioli', 14, Decimal('32'), '24 - 200 g pkgs.', b'\x00', '0'),
#  (43, 'Ipoh Coffee', 20, Decimal('46'), '16 - 500 g tins', b'\x00', '0'),
#  (51, 'Manjimup Dried Apples', 24, Decimal('53'), '50 - 300 g pkgs.', b'\x00', '0'),
# ...

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_html rendered_html output_result"><table>
#     <tbody><tr>
#         <th>Id</th>
#         <th>ProductName</th>
#         <th>SupplierId</th>
#         <th>UnitPrice</th>
#         <th>Package</th>
#         <th>IsDiscontinued</th>
#         <th>BIN(IsDiscontinued)</th>
#     </tr>
#     <tr>
#         <td>59</td>
#         <td>Raclette Courdavault</td>
#         <td>28</td>
#         <td>55.00</td>
#         <td>5 kg pkg.</td>
#         <td>b'\x00'</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>51</td>
#         <td>Manjimup Dried Apples</td>
#         <td>24</td>
#         <td>53.00</td>
#         <td>50 - 300 g pkgs.</td>
#         <td>b'\x00'</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>62</td>
#         <td>Tarte au sucre</td>
#         <td>29</td>
#         <td>49.30</td>
#         <td>48 pies</td>
#         <td>b'\x00'</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>43</td>
#         <td>Ipoh Coffee</td>
#         <td>20</td>
#         <td>46.00</td>
#         <td>16 - 500 g tins</td>
#         <td>b'\x00'</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>28</td>
#         <td>Rössle Sauerkraut</td>
#         <td>12</td>
#         <td>45.60</td>
#         <td>25 - 825 g cans</td>
#         <td>b'\x01'</td>
#         <td>1</td>
#     </tr>
#     <tr>
#         <td>27</td>
#         <td>Schoggi Schokolade</td>
#         <td>11</td>
#         <td>43.90</td>
#         <td>100 - 100 g pieces</td>
#         <td>b'\x00'</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>63</td>
#         <td>Vegie-spread</td>
#         <td>7</td>
#         <td>43.90</td>
#         <td>15 - 625 g jars</td>
#         <td>b'\x00'</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>8</td>
#         <td>Northwoods Cranberry Sauce</td>
#         <td>3</td>
#         <td>40.00</td>
#         <td>12 - 12 oz jars</td>
#         <td>b'\x00'</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>17</td>
#         <td>Alice Mutton</td>
#         <td>7</td>
#         <td>39.00</td>
#         <td>20 - 1 kg tins</td>
#         <td>b'\x01'</td>
#         <td>1</td>
#     </tr>
#     <tr>
#         <td>12</td>
#         <td>Queso Manchego La Pastora</td>
#         <td>5</td>
#         <td>38.00</td>
#         <td>10 - 500 g pkgs.</td>
#         <td>b'\x00'</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>56</td>
#         <td>Gnocchi di nonna Alice</td>
#         <td>26</td>
#         <td>38.00</td>
#         <td>24 - 250 g pkgs.</td>
#         <td>b'\x00'</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>69</td>
#         <td>Gudbrandsdalsost</td>
#         <td>15</td>
#         <td>36.00</td>
#         <td>10 kg pkg.</td>
#         <td>b'\x00'</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>72</td>
#         <td>Mozzarella di Giovanni</td>
#         <td>14</td>
#         <td>34.80</td>
#         <td>24 - 200 g pkgs.</td>
#         <td>b'\x00'</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>60</td>
#         <td>Camembert Pierrot</td>
#         <td>28</td>
#         <td>34.00</td>
#         <td>15 - 300 g rounds</td>
#         <td>b'\x00'</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>64</td>
#         <td>Wimmers gute Semmelknödel</td>
#         <td>12</td>
#         <td>33.25</td>
#         <td>20 bags x 4 pieces</td>
#         <td>b'\x00'</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>53</td>
#         <td>Perth Pasties</td>
#         <td>24</td>
#         <td>32.80</td>
#         <td>48 pieces</td>
#         <td>b'\x01'</td>
#         <td>1</td>
#     </tr>
#     <tr>
#         <td>32</td>
#         <td>Mascarpone Fabioli</td>
#         <td>14</td>
#         <td>32.00</td>
#         <td>24 - 200 g pkgs.</td>
#         <td>b'\x00'</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>26</td>
#         <td>Gumbär Gummibärchen</td>
#         <td>11</td>
#         <td>31.23</td>
#         <td>100 - 250 g bags</td>
#         <td>b'\x00'</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>10</td>
#         <td>Ikura</td>
#         <td>4</td>
#         <td>31.00</td>
#         <td>12 - 200 ml jars</td>
#         <td>b'\x00'</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>7</td>
#         <td>Uncle Bob's Organic Dried Pears</td>
#         <td>3</td>
#         <td>30.00</td>
#         <td>12 - 1 lb pkgs.</td>
#         <td>b'\x00'</td>
#         <td>0</td>
#     </tr>
# </tbody></table></div>
#
# </details>

# %%
# Câu 4: Liệt kê danh sách tất cả các sản phẩm có đơn giá lớn hơn 60 usd và đã ngưng bán
q = "select p.*, BIN(p.isdiscontinued) from products p where p.unitprice > 60 and p.isdiscontinued = 1"
# %sql $q
# Out:
#  * mysql+pymysql://root:***@localhost/salesdb?charset=UTF8
# 2 rows affected.
# [(9, 'Mishi Kobe Niku', 4, Decimal('100'), '18 - 500 g pkgs.', b'\x01', '1'),
#  (29, 'Thüringer Rostbratwurst', 12, Decimal('124'), '50 bags x 30 sausgs.', b'\x01', '1')]

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_html rendered_html output_result"><table>
#     <tbody><tr>
#         <th>Id</th>
#         <th>ProductName</th>
#         <th>SupplierId</th>
#         <th>UnitPrice</th>
#         <th>Package</th>
#         <th>IsDiscontinued</th>
#     </tr>
#     <tr>
#         <td>9</td>
#         <td>Mishi Kobe Niku</td>
#         <td>4</td>
#         <td>97.00</td>
#         <td>18 - 500 g pkgs.</td>
#         <td>b'\x01'</td>
#     </tr>
#     <tr>
#         <td>29</td>
#         <td>Thüringer Rostbratwurst</td>
#         <td>12</td>
#         <td>123.79</td>
#         <td>50 bags x 30 sausgs.</td>
#         <td>b'\x01'</td>
#     </tr>
# </tbody></table></div>
#
# </details>

# %%
# Câu 5: Liệt kê danh sách các khách hàng trong tên có 2 chữ 'o' (vd: Antonio)
q = "select * from customers where lastname like '%o%o%' "
# %sql $q
# Out:
#  * mysql+pymysql://root:***@localhost/salesdb?charset=UTF8
# 6 rows affected.
# [(3, 'Antonio', 'Moreno', 'México D.F.', 'Mexico', '(5) 555-3932'),
#  (6, 'Hanna', 'Moos', 'Mannheim', 'Germany', '0621-08460'),
#  (15, 'Pedro', 'Afonso', 'Sao Paulo', 'Brazil', '(11) 555-7647'),
#  (66, 'Maurizio', 'Moroni', 'Reggio Emilia', 'Italy', '0522-556721'),
#  (80, 'Miguel', 'Angel Paolino', 'México D.F.', 'Mexico', '(5) 555-2933'),
#  (87, 'Pirkko', 'Koskitalo', 'Oulu', 'Finland', '981-443655')]

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_html rendered_html output_result"><table>
#     <tbody><tr>
#         <th>Id</th>
#         <th>FirstName</th>
#         <th>LastName</th>
#         <th>City</th>
#         <th>Country</th>
#         <th>Phone</th>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>Antonio</td>
#         <td>Moreno</td>
#         <td>México D.F.</td>
#         <td>Mexico</td>
#         <td>(5) 555-3932</td>
#     </tr>
#     <tr>
#         <td>6</td>
#         <td>Hanna</td>
#         <td>Moos</td>
#         <td>Mannheim</td>
#         <td>Germany</td>
#         <td>0621-08460</td>
#     </tr>
#     <tr>
#         <td>15</td>
#         <td>Pedro</td>
#         <td>Afonso</td>
#         <td>Sao Paulo</td>
#         <td>Brazil</td>
#         <td>(11) 555-7647</td>
#     </tr>
#     <tr>
#         <td>66</td>
#         <td>Maurizio</td>
#         <td>Moroni</td>
#         <td>Reggio Emilia</td>
#         <td>Italy</td>
#         <td>0522-556721</td>
#     </tr>
#     <tr>
#         <td>80</td>
#         <td>Miguel</td>
#         <td>Angel Paolino</td>
#         <td>México D.F.</td>
#         <td>Mexico</td>
#         <td>(5) 555-2933</td>
#     </tr>
#     <tr>
#         <td>87</td>
#         <td>Pirkko</td>
#         <td>Koskitalo</td>
#         <td>Oulu</td>
#         <td>Finland</td>
#         <td>981-443655</td>
#     </tr>
# </tbody></table></div>
#
# </details>

# %%
# Câu 6: Liệt kê danh sách các khách hàng có tên bắt đầu bằng chữ 'A' và kết thúc bằng chữ 'o' hoặc ở thành phố bắt đầu bằng 'Ma'
q = "select * from customers where lastname like 'A%o' or city like 'Ma%' "
# %sql $q
# Out:
#  * mysql+pymysql://root:***@localhost/salesdb?charset=UTF8
# 7 rows affected.
# [(6, 'Hanna', 'Moos', 'Mannheim', 'Germany', '0621-08460'),
#  (8, 'Martín', 'Sommer', 'Madrid', 'Spain', '(91) 555 22 82'),
#  (9, 'Laurence', 'Lebihan', 'Marseille', 'France', '91.24.45.40'),
#  (15, 'Pedro', 'Afonso', 'Sao Paulo', 'Brazil', '(11) 555-7647'),
#  (22, 'Diego', 'Roel', 'Madrid', 'Spain', '(91) 555 94 44'),
#  (69, 'Alejandra', 'Camino', 'Madrid', 'Spain', '(91) 745 6200'),
#  (80, 'Miguel', 'Angel Paolino', 'México D.F.', 'Mexico', '(5) 555-2933')]

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_html rendered_html output_result"><table>
#     <tbody><tr>
#         <th>Id</th>
#         <th>FirstName</th>
#         <th>LastName</th>
#         <th>City</th>
#         <th>Country</th>
#         <th>Phone</th>
#     </tr>
#     <tr>
#         <td>6</td>
#         <td>Hanna</td>
#         <td>Moos</td>
#         <td>Mannheim</td>
#         <td>Germany</td>
#         <td>0621-08460</td>
#     </tr>
#     <tr>
#         <td>8</td>
#         <td>Martín</td>
#         <td>Sommer</td>
#         <td>Madrid</td>
#         <td>Spain</td>
#         <td>(91) 555 22 82</td>
#     </tr>
#     <tr>
#         <td>9</td>
#         <td>Laurence</td>
#         <td>Lebihan</td>
#         <td>Marseille</td>
#         <td>France</td>
#         <td>91.24.45.40</td>
#     </tr>
#     <tr>
#         <td>15</td>
#         <td>Pedro</td>
#         <td>Afonso</td>
#         <td>Sao Paulo</td>
#         <td>Brazil</td>
#         <td>(11) 555-7647</td>
#     </tr>
#     <tr>
#         <td>22</td>
#         <td>Diego</td>
#         <td>Roel</td>
#         <td>Madrid</td>
#         <td>Spain</td>
#         <td>(91) 555 94 44</td>
#     </tr>
#     <tr>
#         <td>69</td>
#         <td>Alejandra</td>
#         <td>Camino</td>
#         <td>Madrid</td>
#         <td>Spain</td>
#         <td>(91) 745 6200</td>
#     </tr>
#     <tr>
#         <td>80</td>
#         <td>Miguel</td>
#         <td>Angel Paolino</td>
#         <td>México D.F.</td>
#         <td>Mexico</td>
#         <td>(5) 555-2933</td>
#     </tr>
# </tbody></table></div>
#
# </details>
