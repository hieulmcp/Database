# %%
# %load_ext sql
import pandas as pd

# %%
# chuoi ket noi
user = 'hv'
password = '123456'
connection_string = "mysql+pymysql://{user}:{password}@phpmyadmin.laptrinhphp.net/gd_salesdb?charset=UTF8".format(user=user, password=password)
# %sql $connection_string

# %%
# thuc hien cau truy van, ket qua tra ve luu trong dataframe
# %sql select * from customers where country='Germany'
# Out:
#  * mysql+pymysql://hv:***@phpmyadmin.laptrinhphp.net/gd_salesdb?charset=UTF8
# 11 rows affected.
# [(1, 'Maria', 'Anders', 'Berlin', 'Germany', '030-0074321'),
#  (6, 'Hanna', 'Moos', 'Mannheim', 'Germany', '0621-08460'),
#  (17, 'Sven', 'Ottlieb', 'Aachen', 'Germany', '0241-039123'),
#  (25, 'Peter', 'Franken', 'München', 'Germany', '089-0877310'),
#  (39, 'Philip', 'Cramer', 'Brandenburg', 'Germany', '0555-09876'),
#  (44, 'Renate', 'Messner', 'Frankfurt a.M.', 'Germany', '069-0245984'),
#  (52, 'Alexander', 'Feuer', 'Leipzig', 'Germany', '0342-023176'),
#  (56, 'Henriette', 'Pfalzheim', 'Köln', 'Germany', '0221-0644327'),
#  (63, 'Horst', 'Kloss', 'Cunewalde', 'Germany', '0372-035188'),
#  (79, 'Karin', 'Josephs', 'Münster', 'Germany', '0251-031259'),
#  (86, 'Rita', 'Müller', 'Stuttgart', 'Germany', '0711-020361')]

# %%
data = %sql select * from customers where country='Germany'
df = data.DataFrame()
df
# Out:
#  * mysql+pymysql://hv:***@phpmyadmin.laptrinhphp.net/gd_salesdb?charset=UTF8
# 11 rows affected.
#     Id  FirstName   LastName            City  Country         Phone
# 0    1      Maria     Anders          Berlin  Germany   030-0074321
# 1    6      Hanna       Moos        Mannheim  Germany    0621-08460
# 2   17       Sven    Ottlieb          Aachen  Germany   0241-039123
# 3   25      Peter    Franken         München  Germany   089-0877310
# 4   39     Philip     Cramer     Brandenburg  Germany    0555-09876
# 5   44     Renate    Messner  Frankfurt a.M.  Germany   069-0245984
# 6   52  Alexander      Feuer         Leipzig  Germany   0342-023176
# 7   56  Henriette  Pfalzheim            Köln  Germany  0221-0644327
# 8   63      Horst      Kloss       Cunewalde  Germany   0372-035188
# 9   79      Karin    Josephs         Münster  Germany   0251-031259
# 10  86       Rita     Müller       Stuttgart  Germany   0711-020361

# %%
df.shape
# Out:
# (11, 6)

# %%
df
# Out:
#     Id  FirstName   LastName            City  Country         Phone
# 0    1      Maria     Anders          Berlin  Germany   030-0074321
# 1    6      Hanna       Moos        Mannheim  Germany    0621-08460
# 2   17       Sven    Ottlieb          Aachen  Germany   0241-039123
# 3   25      Peter    Franken         München  Germany   089-0877310
# 4   39     Philip     Cramer     Brandenburg  Germany    0555-09876
# 5   44     Renate    Messner  Frankfurt a.M.  Germany   069-0245984
# 6   52  Alexander      Feuer         Leipzig  Germany   0342-023176
# 7   56  Henriette  Pfalzheim            Köln  Germany  0221-0644327
# 8   63      Horst      Kloss       Cunewalde  Germany   0372-035188
# 9   79      Karin    Josephs         Münster  Germany   0251-031259
# 10  86       Rita     Müller       Stuttgart  Germany   0711-020361

# %%
user = 'root'
password = ''
connection_string = "mysql+pymysql://{user}:{password}@localhost:3306/humanresources?charset=UTF8".format(user=user, password=password)
# %sql $connection_string

# %%
data = %sql select * from employees
df = data.DataFrame()
df
# Out:
#    mysql+pymysql://hv:***@phpmyadmin.laptrinhphp.net/gd_salesdb?charset=UTF8
#  * mysql+pymysql://root:***@localhost:3306/humanresources?charset=UTF8
# 107 rows affected.
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  \
# 0            100     STEVEN      KING     SKING  515.123.4567
# 1            101      NEENA   KOCHHAR  NKOCHHAR  515.123.4568
# 2            102        LEX   DE HAAN   LDEHAAN  515.123.4569
# 3            103  ALEXANDER    HUNOLD   AHUNOLD  590.423.4567
# 4            104      BRUCE     ERNST    BERNST  590.423.4568
# ..           ...        ...       ...       ...           ...
# 102          202        PAT       FAY      PFAY  603.123.6666
# 103          203      SUSAN    MAVRIS   SMAVRIS  515.123.7777
# 104          204    HERMANN      BAER     HBAER  515.123.8888
# 105          205    SHELLEY   HIGGINS  SHIGGINS  515.123.8080
# 106          206    WILLIAM     GIETZ    WGIETZ  515.123.8181
#
# ...
